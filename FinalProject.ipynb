# %% [markdown]
# <a href="https://colab.research.google.com/github/jakefraser04/BigDataFinalProject/blob/main_dev/FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proposal

# %% [markdown]
# # Data Loading

# %%
import zipfile

# Connect to google drive
from google.colab import drive
drive.mount('/content/drive')

zip_path = "/content/drive/MyDrive/Airbnb 3.zip"

with zipfile.ZipFile(zip_path, 'r') as zip_files:
    zip_files.extractall("/content/airbnb_extracted")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

for root, dirs, files in os.walk("/content", topdown=True):
    for f in files:
        if "listings" in f.lower():
            print(os.path.join(root, f))
# Out:
# /content/airbnb_extracted/Airbnb 3/Madrid/listings.csv
# /content/airbnb_extracted/Airbnb 3/Madrid/listings.csv.gz
# /content/airbnb_extracted/Airbnb 3/Buenos Aires/listings.csv
# /content/airbnb_extracted/Airbnb 3/Buenos Aires/listings.csv.gz
# /content/airbnb_extracted/Airbnb 3/Malaga/listings.csv
# /content/airbnb_extracted/Airbnb 3/Malaga/listings.csv.gz
# /content/airbnb_extracted/Airbnb 3/Los Angeles/listings.csv
# /content/airbnb_extracted/Airbnb 3/Los Angeles/listings.csv.gz
# /content/airbnb_extracted/Airbnb 3/New York City/listings.csv
# /content/airbnb_extracted/Airbnb 3/New York City/listings.csv.gz
# /content/airbnb_extracted/Airbnb 3/Berlin/listings.csv
# /content/airbnb_extracted/Airbnb 3/Berlin/listings.csv.gz
# /content/airbnb_extracted/Airbnb 3/Valencia/listings.csv
# /content/airbnb_extracted/Airbnb 3/Valencia/listings.csv.gz
# /content/airbnb_extracted/Airbnb 3/Paris/listings.csv
# /content/airbnb_extracted/Airbnb 3/Paris/listings.csv.gz
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Exporatory Data Analysis

# %% [markdown]
# # Machine Learning

# %% [markdown]
# # Insights and Conclusions
