# %% [markdown]
# <a href="https://colab.research.google.com/github/yiyangquek/BigDataFinalProject/blob/Yiyang/FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello My name is Jake")
# Out:
# Hello My name is Jake

# %%
print("Hi Yiyang")
# Out:
# Hi Yiyang
