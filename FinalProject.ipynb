# %% [markdown]
# <a href="https://colab.research.google.com/github/jakefraser04/BigDataFinalProject/blob/main/FinalProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proposal

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Exporatory Data Analysis

# %% [markdown]
# # Machine Learning

# %% [markdown]
# # Insights and Conclusions
